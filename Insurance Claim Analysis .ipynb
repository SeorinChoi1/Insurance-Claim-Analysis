# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/choeseolin/Downloads/Portofoilo/Data for Portofolio/insurance_data.csv")
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df=df.drop(columns = 'index')
df
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             1  39.0    male  23.2             91      Yes         0     No
# 1             2  24.0    male  30.1             87       No         0     No
# 2             3   NaN    male  33.3             82      Yes         0     No
# 3             4   NaN    male  33.7             80       No         0     No
# 4             5   NaN    male  34.1            100       No         0     No
# ...         ...   ...     ...   ...            ...      ...       ...    ...
# 1335       1336  44.0  female  35.5             88      Yes         0    Yes
# 1336       1337  59.0  female  38.1            120       No         1    Yes
# 1337       1338  30.0    male  34.5             91      Yes         3    Yes
# 1338       1339  37.0    male  30.4            106       No         0    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim
# ...

# %%
df=df.fillna('')
df
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             1  39.0    male  23.2             91      Yes         0     No
# 1             2  24.0    male  30.1             87       No         0     No
# 2             3          male  33.3             82      Yes         0     No
# 3             4          male  33.7             80       No         0     No
# 4             5          male  34.1            100       No         0     No
# ...         ...   ...     ...   ...            ...      ...       ...    ...
# 1335       1336  44.0  female  35.5             88      Yes         0    Yes
# 1336       1337  59.0  female  38.1            120       No         1    Yes
# 1337       1338  30.0    male  34.5             91      Yes         3    Yes
# 1338       1339  37.0    male  30.4            106       No         0    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim
# ...

# %%
df.sort_values(by="bmi", ascending=False).head(10)
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 9            10  30.0    male  53.1             97       No         0     No
# 1299       1300  50.0    male  52.6            110       No         1    Yes
# 141         142  46.0    male  50.4             89      Yes         1     No
# 802         803  42.0    male  49.1            109      Yes         0     No
# 675         676  49.0  female  48.1             81      Yes         2     No
# 696         697  49.0    male  47.7             88       No         1     No
# 1306       1307  43.0  female  47.6            112      Yes         2    Yes
# 579         580  25.0    male  47.5             84      Yes         1     No
# 1339       1340  30.0  female  47.4            101       No         0    Yes
# 880         881  28.0  female  46.8            106       No         5     No
#
#          region     claim
# 9     northwest   1163.46
# 1299  southeast  44501.40
# 141   southeast   2438.06
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                PatientID       bmi  bloodpressure  children     claim
# PatientID       1.000000  0.115129       0.450602  0.128104  0.879268
# bmi             0.115129  1.000000       0.143544  0.012092  0.197401
# bloodpressure   0.450602  0.143544       1.000000 -0.031682  0.531341
# children        0.128104  0.012092      -0.031682  1.000000  0.069233
# claim           0.879268  0.197401       0.531341  0.069233  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.rcParams['figure.figsize'] = (15,5)
plt.show()

# %%
df=df.groupby('gender').mean(numeric_only=True).sort_values(by='claim', ascending= False)
df
# Out:
#          PatientID        bmi  bloodpressure  children         claim
# gender
# male    673.265487  30.951327      94.297935  1.112094  13919.790457
# female  667.667674  30.379758      94.013595  1.074018  12569.578897

# %%
df.columns
# Out:
# Index(['PatientID', 'bmi', 'bloodpressure', 'children', 'claim'], dtype='object')

# %%
df2=df.transpose()
df2
# Out:
# gender                 male        female
# PatientID        673.265487    667.667674
# bmi               30.951327     30.379758
# bloodpressure     94.297935     94.013595
# children           1.112094      1.074018
# claim          13919.790457  12569.578897

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df2.plot(kind='bar', title=' Values By Gender Group')
plt.ylabel('Mean Value')
plt.xlabel('Features')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.transpose(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Mean Feature Values by Gender (Heatmap)')
plt.xlabel('Gender')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()
